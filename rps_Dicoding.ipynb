# %%
import os
import tensorflow as tf
print("tensorflow version = {}".format(tf.__version__))
print("keras version = {}".format(tf.keras.__version__))
# Out:
# tensorflow version = 2.4.1
# keras version = 2.4.0

# %%
dataDir = 'rockpaperscissors'
os.listdir(dataDir)
# Out:
# ['paper', 'README_rpc-cv-images.txt', 'rock', 'scissors']

# %%
import pathlib

image_count = len(list(pathlib.Path(dataDir).glob('*/*.PNG')))
print(image_count)
# Out:
# 2188

# %%
from PIL import Image

rock = list(pathlib.Path(dataDir).glob("rock/*"))
Image.open(str(rock[1]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x200 at 0x25A1E777E80>

# %%
paper = list(pathlib.Path(dataDir).glob("paper/*"))
Image.open(str(paper[1]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x200 at 0x25A1E7AFA90>

# %%
scissors = list(pathlib.Path(dataDir).glob("scissors/*"))
Image.open(str(scissors[1]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x200 at 0x25A1E777820>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    validation_split = 0.4,
    rescale = 1./255,
    rotation_range = 20,
    horizontal_flip = True,
    shear_range = 0.2,
    zoom_range=0.2,
    fill_mode = 'nearest'
)

# %%
imgHeight = 150
imgWidth = 150

trainGenerator = datagen.flow_from_directory(
    dataDir,
    subset = "training",
    seed = 42,
    target_size = (imgHeight, imgWidth),    
)

valGenerator = datagen.flow_from_directory(
    dataDir,
    subset = "validation",
    seed = 42,
    target_size = (imgHeight, imgWidth),    
)
numClasses = trainGenerator.num_classes
# Out:
# Found 1314 images belonging to 3 classes.
# Found 874 images belonging to 3 classes.

# %%
def generatorToTfdata(generator, input_shape):
    numClasses = generator.num_classes
    tfGenerator = tf.data.Dataset.from_generator(
        lambda: generator,
        output_types=(tf.float32, tf.float32),
        output_shapes=([None,
        input_shape[0],
        input_shape[1],
        input_shape[2]],
        [None, numClasses])
    )
    return tfGenerator

trainTfData = generatorToTfdata(trainGenerator, trainGenerator.image_shape)

valTfData = generatorToTfdata(valGenerator, valGenerator.image_shape)

# %%
print("type datagenerator: {}".format(type(trainGenerator)))
print("type ts_data: {}".format(type(trainTfData)))
# Out:
# type datagenerator: <class 'tensorflow.python.keras.preprocessing.image.DirectoryIterator'>
# type ts_data: <class 'tensorflow.python.data.ops.dataset_ops.FlatMapDataset'>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

model = Sequential([
    layers.ZeroPadding2D(padding=(2, 2), input_shape=(150, 150, 3)),
    layers.Conv2D(16, (5, 5), strides=(1, 1), activation='relu'),
    layers.MaxPooling2D(2, 2),
    layers.Conv2D(32, (3, 3), strides=(1, 1), activation='relu'),
    layers.MaxPooling2D(2, 2),
    layers.Conv2D(32, (3, 3), strides=(1, 1), activation='relu'),
    layers.Conv2D(64, (3, 3), strides=(1, 1), activation='relu'),
    layers.ZeroPadding2D(padding=(2, 2)),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(numClasses, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 154, 154, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 150, 150, 16)      1216
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 73, 73, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 36, 36, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 36, 36, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 82944)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               21233920
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 21,284,163
# Trainable params: 21,284,163
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = tf.keras.optimizers.Adam(lr=0.0001)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

# %%
callbacks = tf.keras.callbacks.TensorBoard(log_dir='./Graph')
history = model.fit(
      trainTfData,
      steps_per_epoch=10,  # berapa batch yang akan dieksekusi pada setiap epoch
      epochs=45,
      validation_data=valTfData, # menampilkan akurasi pengujian data validasi
      validation_steps=5,  # berapa batch yang akan dieksekusi pada setiap epoch
      verbose=1,
      callbacks=[callbacks])
# Out:
# Epoch 1/45
# 10/10 [==============================] - 27s 3s/step - loss: 1.0995 - accuracy: 0.3810 - val_loss: 1.0527 - val_accuracy: 0.4250
# Epoch 2/45
# 10/10 [==============================] - 27s 3s/step - loss: 1.0016 - accuracy: 0.6286 - val_loss: 0.9637 - val_accuracy: 0.4875
# Epoch 3/45
# 10/10 [==============================] - 22s 2s/step - loss: 0.8817 - accuracy: 0.6358 - val_loss: 0.7917 - val_accuracy: 0.6687
# Epoch 4/45
# 10/10 [==============================] - 25s 3s/step - loss: 0.7309 - accuracy: 0.6993 - val_loss: 0.7095 - val_accuracy: 0.6938
# Epoch 5/45
# 10/10 [==============================] - 19s 2s/step - loss: 0.6039 - accuracy: 0.8010 - val_loss: 0.5696 - val_accuracy: 0.7937
# Epoch 6/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.6248 - accuracy: 0.7702 - val_loss: 0.5302 - val_accuracy: 0.7899
# Epoch 7/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.6059 - accuracy: 0.7704 - val_loss: 0.5693 - val_accuracy: 0.7812
# Epoch 8/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.4904 - accuracy: 0.8247 - val_loss: 0.5872 - val_accuracy: 0.7563
# Epoch 9/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.5611 - accuracy: 0.7910 - val_loss: 0.4320 - val_accuracy: 0.8313
# Epoch 10/45
# 10/10 [==============================] - 18s 2s/step - loss: 0.5163 - accuracy: 0.8244 - val_loss: 0.5055 - val_accuracy: 0.8313
# Epoch 11/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.4966 - accuracy: 0.8092 - val_loss: 0.4194 - val_accuracy: 0.8062
# Epoch 12/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.3449 - accuracy: 0.8869 - val_loss: 0.3593 - val_accuracy: 0.8768
# Epoch 13/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.3192 - accuracy: 0.8763 - val_loss: 0.3620 - val_accuracy: 0.8750
# Epoch 14/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.3221 - accuracy: 0.9069 - val_loss: 0.2883 - val_accuracy: 0.9062
# Epoch 15/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.2949 - accuracy: 0.9041 - val_loss: 0.3001 - val_accuracy: 0.8875
# Epoch 16/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.2933 - accuracy: 0.9201 - val_loss: 0.2917 - val_accuracy: 0.8875
# Epoch 17/45
# 10/10 [==============================] - 15s 2s/step - loss: 0.3052 - accuracy: 0.8956 - val_loss: 0.2949 - val_accuracy: 0.8913
# Epoch 18/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.2625 - accuracy: 0.9272 - val_loss: 0.3171 - val_accuracy: 0.8938
# Epoch 19/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.2187 - accuracy: 0.9216 - val_loss: 0.3005 - val_accuracy: 0.9062
# Epoch 20/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.2335 - accuracy: 0.9241 - val_loss: 0.3349 - val_accuracy: 0.9125
# Epoch 21/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.2735 - accuracy: 0.8939 - val_loss: 0.3178 - val_accuracy: 0.8687
# Epoch 22/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.1840 - accuracy: 0.9623 - val_loss: 0.2240 - val_accuracy: 0.9000
# Epoch 23/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.2061 - accuracy: 0.9411 - val_loss: 0.2347 - val_accuracy: 0.9275
# Epoch 24/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.3108 - accuracy: 0.8777 - val_loss: 0.2587 - val_accuracy: 0.9187
# Epoch 25/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.1781 - accuracy: 0.9488 - val_loss: 0.2827 - val_accuracy: 0.9125
# Epoch 26/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.2673 - accuracy: 0.9091 - val_loss: 0.2185 - val_accuracy: 0.9250
# Epoch 27/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.1652 - accuracy: 0.9463 - val_loss: 0.2008 - val_accuracy: 0.9312
# Epoch 28/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.1574 - accuracy: 0.9543 - val_loss: 0.2176 - val_accuracy: 0.9493
# Epoch 29/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.1952 - accuracy: 0.9559 - val_loss: 0.2588 - val_accuracy: 0.8875
# Epoch 30/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.2678 - accuracy: 0.9038 - val_loss: 0.1788 - val_accuracy: 0.9375
# Epoch 31/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.2100 - accuracy: 0.9336 - val_loss: 0.3089 - val_accuracy: 0.9062
# Epoch 32/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.1490 - accuracy: 0.9606 - val_loss: 0.2619 - val_accuracy: 0.9125
# Epoch 33/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.1950 - accuracy: 0.9506 - val_loss: 0.2647 - val_accuracy: 0.9062
# Epoch 34/45
# 10/10 [==============================] - 15s 2s/step - loss: 0.1561 - accuracy: 0.9468 - val_loss: 0.1751 - val_accuracy: 0.9493
# Epoch 35/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.1197 - accuracy: 0.9589 - val_loss: 0.1236 - val_accuracy: 0.9688
# Epoch 36/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.1458 - accuracy: 0.9420 - val_loss: 0.1467 - val_accuracy: 0.9563
# Epoch 37/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.1186 - accuracy: 0.9562 - val_loss: 0.1562 - val_accuracy: 0.9563
# Epoch 38/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.1578 - accuracy: 0.9370 - val_loss: 0.2336 - val_accuracy: 0.9125
# Epoch 39/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.1146 - accuracy: 0.9714 - val_loss: 0.1483 - val_accuracy: 0.9438
# Epoch 40/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.1186 - accuracy: 0.9639 - val_loss: 0.2002 - val_accuracy: 0.9348
# Epoch 41/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.1207 - accuracy: 0.9557 - val_loss: 0.2100 - val_accuracy: 0.9250
# Epoch 42/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.1223 - accuracy: 0.9625 - val_loss: 0.2049 - val_accuracy: 0.9187
# Epoch 43/45
# 10/10 [==============================] - 17s 2s/step - loss: 0.1505 - accuracy: 0.9390 - val_loss: 0.2358 - val_accuracy: 0.9062
# Epoch 44/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.1399 - accuracy: 0.9320 - val_loss: 0.1089 - val_accuracy: 0.9500
# Epoch 45/45
# 10/10 [==============================] - 16s 2s/step - loss: 0.0954 - accuracy: 0.9651 - val_loss: 0.1272 - val_accuracy: 0.9638

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, axes = plt.subplots(1, 2, figsize=(11, 2))
ax = axes.ravel()

ax[0].plot(history.history['loss'])
ax[0].plot(history.history['val_loss'])

ax[0].legend(['loss', 'val_loss'])
ax[0].set_xlim([0, len(history.history['loss'])-0.95])
ax[0].set_ylim([min(history.history['val_loss'])-0.2, max(history.history['val_loss'])+0.2])

ax[1].plot(history.history['accuracy'])
ax[1].plot(history.history['val_accuracy'])

ax[1].legend(['accuracy', 'val_accuracy'])
ax[1].set_xlim([0, len(history.history['accuracy'])-0.95])
ax[1].set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
model.save_weights('weights.h5')
